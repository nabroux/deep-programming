# %% [markdown]
# # 105306076 資管四 許雲輔 建築師巴布 - 菱形塔

# %%
size = int(input('請輸入菱形的層數(僅限奇數)： '))
line=''

structure = list(range(1,int(size)+1))[::2] + list(range(int(size)-2,0,-1))[::2]
    
for i in structure:
    line += int((size-i)/2) * ' ' + i * '*' + '\n'

print(line)
# Out:
# 請輸入菱形的層數(僅限奇數)： 55
#                            *
#                           ***
#                          *****
#                         *******
#                        *********
#                       ***********
#                      *************
#                     ***************
#                    *****************
#                   *******************
#                  *********************
#                 ***********************
#                *************************
#               ***************************
#              *****************************
#             *******************************
#            *********************************
#           ***********************************
#          *************************************
#         ***************************************
#        *****************************************
#       *******************************************
#      *********************************************
# ...
