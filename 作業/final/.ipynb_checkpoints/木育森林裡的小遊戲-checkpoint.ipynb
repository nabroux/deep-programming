# %% [markdown]
# # 105306076 資管四 許雲輔 木育森林裡的小遊戲

# %%
import random
desk={'A':'3','B':'5','C':'7'}
# ~ print(desk)
bad_str = '100 500 220 330 140 260 370 540 144 224 246 334 347 111 115 155 356 136 235 257 123 127'.split()
pattern = 'O '
bad = [{'0':2,'1':1},{'0':2,'5':1},{'0':1,'2':2},{'0':1,'3':2},{'1':1,'4':2},{'1':2,'5':1},{'1':1,'5':2},{'3':2,'4':1},\
    {'1':3},{'0':1,'1':1,'4':1},{'0':1,'2':1,'6':1},{'0':1,'3':1,'7':1},{'0':1,'4':1,'5':1},{'2':1,'4':1,'6':1},\
    {'3':1,'4':1,'7':1},{'3':1,'5':1,'6':1},{'1':1,'3':1,'6':1},{'2':1,'3':1,'5':1},{'2':1,'5':1,'7':1},{'1':1,'2':1,'3':1},{'1':1,'2':1,'7':1}]

def show_info():
    print()
    for d,dn in desk.items():
        if int(dn) >1:
            print('盤子 '+d+' 有 '+dn+' 顆石頭')
        else:
            print('盤子 '+d+' 有 '+dn+' 顆石頭')
        print((pattern+' ')*int(dn))
    print()

def AI_move():
    print()
    current_stn = list(desk.values())
    current_dict = {}
    possibles = []
    for stn in current_stn:
        if stn not in current_dict:
            n = current_stn.count(stn)
            current_dict[stn] = n
    
    for b in bad:
        count = 0
        b_left = b.copy()
        current_dict_left = current_dict.copy()
        for stn in current_dict:
            if stn in b:
                if current_dict[stn] == b[stn]:
                    count += b[stn]
                    b_left[stn] -= b[stn]
                    current_dict_left[stn] -= b[stn]
                else:
                    count += min(current_dict[stn],b[stn])
                    b_left[stn] -= min(current_dict[stn],b[stn])
                    current_dict_left[stn] -= min(current_dict[stn],b[stn])
                if b_left[stn] == 0:
                    del b_left[stn]
                if current_dict_left[stn] == 0:
                    del current_dict_left[stn]
            
        if count == 2:
            b_new=dict([val,key] for key,val in b_left.items())
            current_dict_new=dict([val,key] for key,val in current_dict_left.items())
            b_new = b_new[1]
            current_dict_new = current_dict_new[1] 
            if int(current_dict_new)-3 <= int(b_new) < int(current_dict_new):
                possibles.append([current_dict_new,b_new])

    if len(possibles)!=0:
        move = random.choice(possibles)
    else:
        dn = list(desk.values())
        move = [max(dn),str(int(max(dn))-1)]
    
    for plate,stones in desk.items():
        if stones == move[0]:
            desk[plate] = move[1]
            print("-----------電腦的回合-------------!")
            print('電腦從盤子',plate,'拿走了',int(move[0])-int(move[1]),'顆石頭')
            show_info()
            break

print('這是一個木育森林裡的小遊戲，因為實在太有意思了，所以把他實作了出來，\n這個遊戲的玩法為兩方輪流從【三盤】石頭中取出石頭')
print('每次只能拿取1~3顆，且不能從不同盤子拿取，拿到最後一顆石頭的一方輸。')
print('準備挑戰超強電腦吧！\n')
print('0為太陽, 1為愛心, 2為太極, 3為星星, 4為骷髏, 5為雪片, 6為笑臉, 7為音符, 8為輻射, 9為飛機')
p_index = int(input('請選擇石頭款式: '))
p_list = ['☀ ','♡ ','☯ ','★ ','☠ ','❄ ','☺ ','♫ ','☢ ','✈']
pattern = p_list[p_index]

show_info()
while True:
    #choose plate
    while True:
        print()
        plate = input('要從哪個盤子拿取石頭呢? ')
        if plate in desk:
            if desk[plate] != '0':
                break
            else:
                print('沒有石頭了')
        else:
            print('請輸入 A 或 B 或 C')
    
    #choose number
    while True:
        print()
        take_num = int(input('要拿多少顆石頭? '))
        if 3>= take_num >=1:
            if int(desk[plate]) >= take_num:
                desk[plate] = str(int(desk[plate])-take_num)
                break
            else:
                print('錯誤！')
        else:
            print('請輸入 1 ~ 3')
    
    current_sum = sum([int(i) for i in desk.values()])
    if current_sum != 0:
        print('-----------你的回合-------------!')
        print('你從盤子',plate,'拿走了',take_num,'顆石頭')
        show_info()
        AI_move()
        current_sum = sum([int(i) for i in desk.values()])
        if current_sum == 0:
            print('【你贏了!】')
            break
    else:
        print('【你輸了!】')
        break
# Out:
# 這是一個木育森林裡的小遊戲，因為實在太有意思了，所以把他實作了出來，
# 這個遊戲的玩法為兩方輪流從【三盤】石頭中取出石頭
# 每次只能拿取1~3顆，且不能從不同盤子拿取，拿到最後一顆石頭的一方輸。
# 準備挑戰超強電腦吧！
#
# 0為太陽, 1為愛心, 2為太極, 3為星星, 4為骷髏, 5為雪片, 6為笑臉, 7為音符, 8為輻射, 9為飛機
# 請選擇石頭款式: 3
#
# 盤子 A 有 3 顆石頭
# ★  ★  ★
# 盤子 B 有 5 顆石頭
# ★  ★  ★  ★  ★
# 盤子 C 有 7 顆石頭
# ★  ★  ★  ★  ★  ★  ★
#
#
# 要從哪個盤子拿取石頭呢? B
#
# 要拿多少顆石頭? 4
# 請輸入 1 ~ 3
#
# 要拿多少顆石頭? 3
# -----------你的回合-------------!
# 你從盤子 B 拿走了 3 顆石頭
#
# 盤子 A 有 3 顆石頭
# ★  ★  ★
# 盤子 B 有 2 顆石頭
# ★  ★
# 盤子 C 有 7 顆石頭
# ★  ★  ★  ★  ★  ★  ★
#
#
# -----------電腦的回合-------------!
# 電腦從盤子 B 拿走了 2 顆石頭
#
# 盤子 A 有 3 顆石頭
# ★  ★  ★
# 盤子 B 有 0 顆石頭
#
# 盤子 C 有 7 顆石頭
# ★  ★  ★  ★  ★  ★  ★
#
#
# 要從哪個盤子拿取石頭呢? V
# 請輸入 A 或 B 或 C
#
# 要從哪個盤子拿取石頭呢? C
#
# 要拿多少顆石頭? 1
# -----------你的回合-------------!
# 你從盤子 C 拿走了 1 顆石頭
#
# 盤子 A 有 3 顆石頭
# ★  ★  ★
# 盤子 B 有 0 顆石頭
#
# 盤子 C 有 6 顆石頭
# ★  ★  ★  ★  ★  ★
#
#
# -----------電腦的回合-------------!
# 電腦從盤子 A 拿走了 1 顆石頭
#
# 盤子 A 有 2 顆石頭
# ★  ★
# 盤子 B 有 0 顆石頭
#
# 盤子 C 有 6 顆石頭
# ★  ★  ★  ★  ★  ★
#
#
# 要從哪個盤子拿取石頭呢? A
#
# 要拿多少顆石頭? 1
# -----------你的回合-------------!
# 你從盤子 A 拿走了 1 顆石頭
#
# 盤子 A 有 1 顆石頭
# ★
# 盤子 B 有 0 顆石頭
#
# 盤子 C 有 6 顆石頭
# ★  ★  ★  ★  ★  ★
#
#
# -----------電腦的回合-------------!
# 電腦從盤子 C 拿走了 2 顆石頭
#
# 盤子 A 有 1 顆石頭
# ★
# 盤子 B 有 0 顆石頭
#
# 盤子 C 有 4 顆石頭
# ★  ★  ★  ★
#
#
# 要從哪個盤子拿取石頭呢? C
#
# 要拿多少顆石頭? 1
# -----------你的回合-------------!
# 你從盤子 C 拿走了 1 顆石頭
#
# 盤子 A 有 1 顆石頭
# ★
# 盤子 B 有 0 顆石頭
#
# 盤子 C 有 3 顆石頭
# ★  ★  ★
#
#
# -----------電腦的回合-------------!
# 電腦從盤子 C 拿走了 3 顆石頭
#
# 盤子 A 有 1 顆石頭
# ★
# 盤子 B 有 0 顆石頭
#
# 盤子 C 有 0 顆石頭
#
#
#
# 要從哪個盤子拿取石頭呢? A
#
# 要拿多少顆石頭? 2
# 錯誤！
#
# 要拿多少顆石頭? 1
# 【你輸了!】
