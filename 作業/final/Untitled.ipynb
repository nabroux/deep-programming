# %%
words = input('please enter what you want to say: ')

print('\n\n')
num = 0.05
for item in words.split():
    print('\n'.join([''.join([(item[(x-y) % len(item)]if
        (( x * num)**2 + (y*0.1)**2 - 1)**3 - (x * num)**2 * (y*0.1)**3 <= 0 else ' ')
    
    for x in range(-30, 30)]) for y in range(12, -12, -1)]))
# Out:
# please enter what you want to say: m
#
#
#
#                 mmmmmmmmm           mmmmmmmmm
#             mmmmmmmmmmmmmmmmm   mmmmmmmmmmmmmmmmm
#           mmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmm
#          mmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmm
#         mmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmm
#         mmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmm
#         mmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmm
#         mmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmm
#         mmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmm
#         mmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmm
#          mmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmm
#           mmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmm
#           mmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmm
#             mmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmm
#              mmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmm
#               mmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmm
#                 mmmmmmmmmmmmmmmmmmmmmmmmmmmmm
#                   mmmmmmmmmmmmmmmmmmmmmmmmm
# ...

# %%
from PIL import Image
import pytesseract
import matplotlib.pyplot as plt

img = Image.open('test.jpg')
plt.imshow(img)
plt.axis('off')
plt.show()
text = pytesseract.image_to_string(img, lang = 'chi_tra')
print(text)
# Out:
# 還沒上傳的程式小作品,
# 請全速上傳! 越多越好!

# %%
#應用程式密碼 ybncczgytybzbyfb
import smtplib
from email.mime.text import MIMEText

gmail_user = 'philasofa@gmail.com'
gmail_password = 'ybncczgytybzbyfb' # your gmail application key

msg = MIMEText('content')
msg['Subject'] = 'Test'
msg['From'] = gmail_user
msg['To'] = '123nabroux@gmail.com'

server = smtplib.SMTP_SSL('smtp.gmail.com', 465)
print(server.ehlo())
server.login(gmail_user, gmail_password)
server.send_message(msg)
server.quit()

print('Email sent!')
# Out:
# (250, b'smtp.gmail.com at your service, [140.119.120.6]\nSIZE 35882577\n8BITMIME\nAUTH LOGIN PLAIN XOAUTH2 PLAIN-CLIENTTOKEN OAUTHBEARER XOAUTH\nENHANCEDSTATUSCODES\nPIPELINING\nCHUNKING\nSMTPUTF8')
# Email sent!
